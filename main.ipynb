# %%
from main import with_lstm, without_lstm, normal
import matplotlib.pyplot as plt 
import pandas as pd 
from src.utils import *
# %matplotlib inline

# %%
arc_with_l, acc_with_lstm, time_with_lstm, history_with_lstm = with_lstm()
arc_without_l, acc_without_lstm, time_without_lstm, history_without_lstm = without_lstm()
arc_normal, acc_normal, time_normal, history_normal = normal()
# Out:
# 375/375 [==============================] - 1s 1ms/step
# 375/375 [==============================] - 0s 989us/step
# 375/375 [==============================] - 0s 1ms/step

# %%
history_with_lstm_dict = convert_history_to_dict(history_with_lstm)
history_without_lstm_dict = convert_history_to_dict(history_without_lstm)

plot_metrics(history_with_lstm_dict, "with lstm")
plot_metrics(history_without_lstm_dict, "without lstm")
plot_metrics(pd.DataFrame(history_normal.history), "normal")

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_with_lstm_dict['accuracy'], marker='o', label='With LSTM')
plt.plot(history_without_lstm_dict['accuracy'], marker='o', label='Without LSTM')
plt.plot(pd.DataFrame(history_normal.history)['accuracy'], marker='o', label='Normal')
plt.title('Accuracy Comparison')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_with_lstm_dict['loss'], marker='o', label='With LSTM')
plt.plot(history_without_lstm_dict['loss'], marker='o', label='Without LSTM')
plt.plot(pd.DataFrame(history_normal.history)['loss'], marker='o', label='Normal')
plt.title('Loss Comparison')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid()
plt.legend()



plt.tight_layout()
plt.show()

# %%
print("Time taken for model with LSTM:", time_with_lstm)
print("Time taken for model without LSTM:", time_without_lstm)
print("Time taken for normal model:", time_normal)
# Out:
# Time taken for model with LSTM: 27.685153245925903
# Time taken for model without LSTM: 0.5650484561920166
# Time taken for normal model: 0.7196230888366699
